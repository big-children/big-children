# %% [markdown]
# <a href="https://colab.research.google.com/github/big-children/big-children/blob/main/Copy_of_Copy_of_B_field_variation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # B-Field Variation
# Does the magnetic field around your workspace have the same magnitude as outside? Perform an investigation to answer that and replace the **pseudocode** below with a [Holmes' t' analysis](https://docs.google.com/document/d/1cjAfYwbG4IrwirHMPnvo87ZYdPTXBAWQAny4b1eVclE/edit?usp=sharing) of data you collect.

# %%
# import modules needed
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import io

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-33ef86a7-a520-49ed-9102-33689433dc11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33ef86a7-a520-49ed-9102-33689433dc11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving day2.csv to day2.csv

# %%
df2 = pd.read_csv(io.BytesIO(uploaded['day2.csv']))

print(df2)
# Out:
#       time     bx    by    bz    bt
# 0    0.0200  17.7 -2.06 -41.7  45.3
# 1    0.0402  17.5 -2.21 -42.9  46.4
# 2    0.0599  15.9 -2.06 -41.4  44.4
# 3    0.0804  16.2 -2.66 -41.0  44.1
# 4    0.1010  16.8 -2.21 -42.3  45.6
# ..      ...   ...   ...   ...   ...
# 470  9.4900  18.7 -3.11 -43.1  47.1
# 471  9.5100  16.6 -3.41 -44.1  47.3
# 472  9.5300  18.1 -4.31 -42.6  46.5
# 473  9.5500  19.0 -1.16 -42.5  46.5
# 474  9.5700  17.1 -2.21 -41.9  45.3
#
# [475 rows x 5 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8e02c586-f963-44f6-8f8d-26026a29a303" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e02c586-f963-44f6-8f8d-26026a29a303">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving day2outside.csv to day2outside.csv

# %%
df1 = pd.read_csv(io.BytesIO(uploaded['day2outside.csv']))

print(df1)
# Out:
#      Time (s)  Magnetic Field x (µT)  Magnetic Field y (µT)  \
# 0      0.0180                   24.0                  -15.3
# 1      0.0380                   25.9                  -16.0
# 2      0.0583                   24.4                  -15.7
# 3      0.0784                   24.4                  -16.0
# 4      0.0986                   26.1                  -15.6
# ..        ...                    ...                    ...
# 491    9.9100                   23.8                  -14.1
# 492    9.9300                   22.9                  -14.8
# 493    9.9500                   24.9                  -15.0
# 494    9.9700                   25.0                  -15.3
# 495    9.9900                   24.4                  -14.4
#
#      Magnetic Field z (µT)  Absolute field (µT)
# 0                    -44.0                 52.3
# 1                    -42.2                 52.0
# 2                    -43.5                 52.3
# 3                    -44.1                 52.9
# ...

# %%
df1['Absolute field (µT)'].describe()
# Out:
# count    496.000000
# mean      52.514516
# std        1.233780
# min       47.900000
# 25%       51.800000
# 50%       52.600000
# 75%       53.300000
# max       55.600000
# Name: Absolute field (µT), dtype: float64

# %%
plt.plot(df2['time ' ], df2['bx'])
plt.title('Magnetic x coordinate by time')
# Out:
# Text(0.5, 1.0, 'Magnetic x coordinate by time')

# %%
plt.hist(df2['bt'],bins=10,range=[10,130], log=False )
plt.hist(df1['Absolute field (µT)'],bins=10,range=[10,130],log=False)
# Out:
# (array([  0.,   0.,   0., 496.,   0.,   0.,   0.,   0.,   0.,   0.]),
#  array([ 10.,  22.,  34.,  46.,  58.,  70.,  82.,  94., 106., 118., 130.]),
#  <a list of 10 Patch objects>)

# %%
# vizualize data to highlight relvant pattern

# vizualize data to highlight relvant pattern
# creates figures in a plot called ax
# makes a space for multiple graphs (horizontal #, vertical #, size - horizontal, vertical)
fig, ax = plt.subplots(2, 2, figsize=(10,5))
# space between plots
fig.subplots_adjust(hspace=.5)

# graph in first row, first column
# makes 
ax[0,0].plot(df1['Time (s)'], df1['Magnetic Field x (µT)'], color= 'blue', label='outside', linestyle="--")
ax[0,0].plot(df2['time '], df2['bt'], color= 'red', label='inside', linestyle="--")
ax[0,0].legend()

# second row, first column
ax[1,0].plot(df1['Time (s)'], df1['Magnetic Field y (µT)'], color= 'blue', label='one', linestyle="--")
ax[1,0].plot(df2['time '], df2['bt'], color= 'red', label='one', linestyle="--")

ax[1,0].annotate('Standard Deviation', xy=(.5, .5), xytext=(.2, .7), arrowprops=dict(facecolor='black', arrowstyle="->"))
ax[1,0].spines['top'].set_visible(False)
ax[1,0].spines['right'].set_visible(False)
ax[1,0].spines['bottom'].set_color('#565656')
ax[1,1].legend()

ax[0,1].plot(df1['Time (s)'], df1['Magnetic Field z (µT)'], color= 'blue', label='outside', linestyle="--")
ax[0,1].plot(df2['time '], df2['bt'], color= 'green', label='inside', linestyle="--")
ax[0,1].set(title="Magnetic Field Comparison") 
ax[0,1].set_xlim(2,5)
ax[0,1].xaxis.set_ticks_position('none')
ax[0,1].tick_params(labelcolor='grey')
ax[0,1].grid(color='#565656', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)
ax[0,1].legend()


ax[1,1].plot(df1['Time (s)'], df1['Absolute field (µT)'], color= 'black', label='outside', linestyle="--")
ax[1,1].plot(df2['time '], df2['bt'], color= 'red', label='inside', linestyle="--")
ax[1,1].legend()


plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# answer the research question in claim-evidence-reasoning style
